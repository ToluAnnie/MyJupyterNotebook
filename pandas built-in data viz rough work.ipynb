# %%
import pandas as pd
import matplotlib.pyplot as plt
df3 = pd.read_csv('df3')
# %matplotlib inline

# %%
df3.head()
# Out:
#           a         b         c         d
# 0  0.336272  0.325011  0.001020  0.401402
# 1  0.980265  0.831835  0.772288  0.076485
# 2  0.480387  0.686839  0.000575  0.746758
# 3  0.502106  0.305142  0.768608  0.654685
# 4  0.856602  0.171448  0.157971  0.321231

# %%
df3.plot.scatter(x='a', y='b', color='red', s=50, figsize=(12,3))
# Out:
# <AxesSubplot:xlabel='a', ylabel='b'>

# %%
df3['a'].hist(color='blue')
# Out:
# <AxesSubplot:>

# %%
df3['a'].plot.hist(bins=25, color='red')
plt.style.use('ggplot')

# %%
df3.boxplot(column=['a','b'])
# Out:
# <AxesSubplot:>

# %%
df3['d'].plot.kde()
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3['d'].plot.kde(lw=6, ls='dotted')
# Out:
# <AxesSubplot:ylabel='Density'>

# %%
df3 = df3.iloc[:31]
df3.plot.area(alpha=0.5)
# Out:
# <AxesSubplot:>

# %%
df3.plot.area(alpha=0.5).legend(loc='center left', bbox_to_anchor=(1.0, 0.5))
